# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ARINDAM
# QC Specialist

# %% [markdown]
# *I am interested in DS because I want to learn and use DS in healthcare industry to solve big data problem in as shorter time span as possible and help patients to improve their lives.*

# %% [markdown]
# Below mentioned code is going to print "Health is wealth"

# %%
print ("Health is wealth")
# Out:
# Health is wealth

# %% [markdown]
# | Name | Occupation | Salary |
# |-----|:-----:|-----:|
# | A | Doctor | $5000 |
# | B | Teacher | &4000 |
#
# (https://www.google.com)
#
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Title Text 1")
#
# ~~scratch this~~
